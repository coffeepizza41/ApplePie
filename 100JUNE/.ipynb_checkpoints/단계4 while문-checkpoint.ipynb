# %% [markdown]
# # A+B -4(*)

# %%
import sys
while True:
    try: # 기본 수행 
        a,b = map(int,sys.stdin.readline().split())
        print(a+b)
    except: # 오류 발생 시 수행
        break

# %% [markdown]
# # A+B -5

# %%
while True: 
    a,b = map(int,input().split())
    if a==0 and b==0:
        break
    print(a+b)
# Out:
# 1 2
# 3
# 3 4
# 7
# 0 0

# %% [markdown]
# # 더하기 싸이클

# %%
n = int(input())
cnt = 0; newn = -1; tmp = n

while newn != tmp: # 새로운 n이 기존 n과 같아지면 stop
    cnt += 1
    sumn = (tmp//10) + (tmp%10) # 십의 자리 + 일의 자리
    newn = (tmp%10)*10 + (sumn%10) # 일의 자리 + 일의 자리
    
print(cnt)
